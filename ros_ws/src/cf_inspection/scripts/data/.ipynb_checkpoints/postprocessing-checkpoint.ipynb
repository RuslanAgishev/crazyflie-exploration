# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw

# %matplotlib inline

# %%
! ls 3_squares/
# Out:
# 2019-08-09-11-36-40  3_squares.png  bag_to_csv.py  coordsXYZ1565339797.95.csv

# %%
points = np.array( pd.read_csv('3_squares/coordsXYZ1565339797.95.csv') )

# %%
x = points[:,0]
y = points[:,1]
z = points[:,2]

# %%
plt.plot(z, '.')

# %%
X = x[350:1000]
Y = y[350:1000]
Z = z[350:1000]
plt.figure(figsize=(10,10))
plt.grid()
plt.plot(X,Y, '.', label='pointcloud')
plt.title('Pointcloud in XY-plane')
plt.legend()

# %%
def convert2map(points, map_pix, map_size, prob):
    """Converts list of XY points to 2D array map in which each pixel denotes
    probability of pixel being occupied.

    Parameters
    ----------
    points : ndarray
        List of XY points measured by sensor in the map reference frame
    map_pix : int
        Size of map pixel in m
    map_size : tuple
        Size of the map in pixels
    prob : float
        Probability


    Returns
    -------
    map : ndarray
        2D array representing map with dtype numpy.float32
    """
    pixels = (points//map_pix).astype(np.int32)
    mask = (pixels[:, 0] >= 0) & (pixels[:, 0] < map_size[0]) & \
           (pixels[:, 1] >= 0) & (pixels[:, 1] < map_size[1])
    pixels = pixels[mask]
    img = Image.new('L', (map_size[1], map_size[0]))

    data = -np.fromstring(img.tobytes(), np.int8).reshape(map_size)
    data[pixels[:, 0], pixels[:, 1]] = 1
    
    return 0.5 + prob*data.astype(np.float32)

# %%
# world params in meters
DIM_X = 5.0 
DIM_Y = 5.0
RESOLUTION = 0.01

LOWEST_X = -2.5
LOWEST_Y = -2.5

grid = np.zeros((int(DIM_X / RESOLUTION), int(DIM_Y / RESOLUTION)))

# %%
# def plot_map(grid, x, y, n):
def plot_map(grid):
    plt.figure(figsize=(12,12))
    plt.imshow(grid.T, cmap='gray', extent=[LOWEST_X, LOWEST_X + DIM_X, LOWEST_Y, LOWEST_Y + DIM_Y])
#     plt.plot(x, y, 'g-', label='Robot path')
#     plt.legend(loc=4)
    plt.xlabel("X, m")
    plt.ylabel("Y, m")
    plt.grid()
    plt.show()
    plt.clf()

# %%
grids = []
for i in range(points.shape[0]):
    # points in map frame:
    points -= np.array([LOWEST_X, LOWEST_Y, 0])
    layer = convert2map(points, RESOLUTION, (int(DIM_X / RESOLUTION), int(DIM_Y / RESOLUTION)), 0.01)
    I = np.log(layer/(1-layer))
    if i == 0:
        I_sum = I
    else:
        I_sum += I
    grids.append(1/(1 + np.exp(-I_sum)))
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:27: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead

# %%
plot_map(1-grids[-1])

# %% [markdown]
# ### Positions of the drone

# %%
cfpose = pd.read_csv('3_squares/2019-08-09-11-36-40/_slash_cf_pose.csv')
scans = pd.read_csv('3_squares/2019-08-09-11-36-40/_slash_multiranger_pointcloud.csv')

# %%
cfpose.head()
# Out:
#        rosbagTimestamp  header  seq  stamp        secs      nsecs  \
# 0  1565339800953013751     NaN   16    NaN  1565339800  951281070
# 1  1565339801053237147     NaN   17    NaN  1565339801   50987958
# 2  1565339801155453370     NaN   18    NaN  1565339801  151844978
# 3  1565339801281290683     NaN   19    NaN  1565339801  265779972
# 4  1565339801353163893     NaN   20    NaN  1565339801  352701902
#
#       frame_id  pose  position         x         y         z  orientation  \
# 0  "base_link"   NaN       NaN -0.339174  0.856681 -0.040429          NaN
# 1  "base_link"   NaN       NaN -0.338963  0.856644 -0.040433          NaN
# 2  "base_link"   NaN       NaN -0.338795  0.856852 -0.040045          NaN
# 3  "base_link"   NaN       NaN -0.338701  0.856959 -0.040052          NaN
# 4  "base_link"   NaN       NaN -0.338868  0.856942 -0.040083          NaN
#
#         x.1       y.1       z.1         w
# 0  0.000293  0.003664  0.003882  0.999986
# 1  0.000287  0.003716  0.003833  0.999986
# 2  0.000304  0.003642  0.003794  0.999986
# 3  0.000322  0.003611  0.003771  0.999986
# 4  0.000285  0.003605  0.003706  0.999987

# %%
scans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1130 entries, 0 to 1129
# Data columns (total 30 columns):
# rosbagTimestamp    1130 non-null int64
# header             0 non-null float64
# seq                1130 non-null int64
# stamp              0 non-null float64
# secs               1130 non-null int64
# nsecs              1130 non-null int64
# frame_id           1130 non-null object
# height             1130 non-null int64
# width              1130 non-null int64
# fields             0 non-null float64
# -                  1130 non-null object
# name               1130 non-null int64
# offset             1130 non-null int64
# datatype           1130 non-null int64
# count              1130 non-null object
# -.1                1130 non-null int64
# name.1             1130 non-null int64
# offset.1           1130 non-null int64
# datatype.1         1130 non-null object
# count.1            1130 non-null int64
# -.2                1130 non-null int64
# name.2             1130 non-null int64
# offset.2           1130 non-null bool
# datatype.2         1130 non-null int64
# count.2            1130 non-null int64
# is_bigendian       1130 non-null object
# point_step         1130 non-null bool
# row_step           0 non-null float64
# data               0 non-null float64
# is_dense           0 non-null float64
# dtypes: bool(2), float64(6), int64(17), object(5)
# memory usage: 249.5+ KB

# %%
plt.figure(figsize=(10,10))
plt.grid()
plt.plot(X,Y, '.', label='pointcloud')
plt.title('Pointcloud in XY-plane')
plt.legend()

plt.plot(cfpose.x, cfpose.y)

# %%
print( len(cfpose.x), len(x) )
# Out:
# 1130 1202

# %% [markdown]
# ### With robot poses

# %%
points = np.array( pd.read_csv('/home/rus/Desktop/coordsXYZ1567006147.68.csv') )

# %%
poses = points[:,:3]

plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
plt.plot(poses[:,0], poses[:,1])
plt.subplot(2,2,2)
plt.plot(poses[:,2][380:1580])

poses.shape
# Out:
# (1983, 3)

# %%
measurements = points[:,3:]`
measurements.shape
# Out:
# (1983, 12)
